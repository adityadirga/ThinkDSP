# %% [markdown]
# <a href="https://colab.research.google.com/github/adityadirga/ThinkDSP/blob/master/Exercise_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Get thinkdsp.py

import os

if not os.path.exists('thinkdsp.py'):
    # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py

# %% [markdown]
# SIGNAL

# %%
from thinkdsp import CosSignal, SinSignal

cos_sig = CosSignal(freq=440, amp=1.0, offset=0)
sin_sig = SinSignal(freq=880, amp=0.5, offset=0)

# %%
# Clone the entire repo.
# !git clone -l -s git://github.com/jakevdp/PythonDataScienceHandbook.git cloned-repo
# %cd cloned-repo
# !ls
# Out:
# Cloning into 'cloned-repo'...
# ...
# remote: Enumerating objects: 1515, done.
# remote: Total 1515 (delta 0), reused 0 (delta 0), pack-reused 1515
# Receiving objects: 100% (1515/1515), 33.14 MiB | 31.10 MiB/s, done.
# Resolving deltas: 100% (1001/1001), done.
# /content/cloned-repo
# environment.yml  LICENSE-TEXT  README.md	 tools
# LICENSE-CODE	 notebooks     requirements.txt  website

# %%
from thinkdsp import decorate

cos_sig.plot()
decorate(xlabel='Time (s)')

# %%
sin_sig.plot()
decorate(xlabel='Time (s)')

# %%
mix = sin_sig + cos_sig
mix

# %%
mix.plot()
decorate(xlabel='Time (s)')

# %% [markdown]
# waves

# %%
wave = mix.make_wave(duration=0.5, start=0, framerate=11025)
wave

# %%
from IPython.display import Audio
audio = Audio(data=wave.ys, rate=wave.framerate)
audio
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print('Number of samples', len(wave.ys))
print('Timestep in ms', 1 / wave.framerate * 1000)
# Out:
# Number of samples 5512
# Timestep in ms 0.09070294784580499

# %%
period = mix.period
segment = wave.segment(start=0, duration=period*3)
period
# Out:
# 0.0022727272727272726

# %%
segment.plot()
decorate(xlabel='Time (s)')

# %%
wave.normalize()
wave.apodize()
wave.plot()
decorate(xlabel='Time (s)')

# %%
wave.write('temp.wav')
# Out:
# Writing temp.wav

# %%
from thinkdsp import play_wave

play_wave(filename='temp.wav', player='aplay')

# %%
from thinkdsp import read_wave

wave = read_wave('92002__jcveliz__violin-origional.wav')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-1e5d37415dcf> in <module>()
#       1 from thinkdsp import read_wave
#       2
# ----> 3 wave = read_wave('92002__jcveliz__violin-origional.wav')
#
# /content/thinkdsp.py in read_wave(filename)
#      96     returns: Wave
#      97     """
# ---> 98     fp = open_wave(filename, "r")
#      99
#     100     nchannels = fp.getnchannels()
#
# /usr/lib/python3.6/wave.py in open(f, mode)
#     497             mode = 'rb'
#     498     if mode in ('r', 'rb'):
# --> 499         return Wave_read(f)
#     500     elif mode in ('w', 'wb'):
#     501         return Wave_write(f)
#
# /usr/lib/python3.6/wave.py in __init__(self, f)
#     157         self._i_opened_the_file = None
#     158         if isinstance(f, str):
# --> 159             f = builtins.open(f, 'rb')
#     160             self._i_opened_the_file = f
# ...

# %%
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
start = 1.2
duration = 0.6
segment = wave.segment(start, duration)
segment.plot()
decorate(xlabel='Time (s)')

# %%
spectrum = segment.make_spectrum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-93304cd0c403> in <module>()
# ----> 1 spectrum = segment.make_spectrum()
#
# /content/thinkdsp.py in make_spectrum(self, full)
#     958             fs = np.fft.fftfreq(n, d)
#     959         else:
# --> 960             hs = np.fft.rfft(self.ys)
#     961             fs = np.fft.rfftfreq(n, d)
#     962
#
# <__array_function__ internals> in rfft(*args, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/numpy/fft/_pocketfft.py in rfft(a, n, axis, norm)
#     372             n = a.shape[axis]
#     373         inv_norm = sqrt(n)
# --> 374     output = _raw_fft(a, n, axis, True, True, inv_norm)
#     375     return output
#     376
#
# /usr/local/lib/python3.6/dist-packages/numpy/fft/_pocketfft.py in _raw_fft(a, n, axis, is_real, is_forward, inv_norm)
#      56     if n < 1:
# ...
